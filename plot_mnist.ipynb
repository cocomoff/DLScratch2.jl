# %%
using Flux
using Flux.Data.MNIST
using Images
# Out:
# ┌ Info: Recompiling stale cache file C:\Users\KO\.julia\compiled\v1.0\Images\H8Vxc.ji for Images [916415d5-f1e6-5110-898d-aaa5f9f070e0]
# └ @ Base loading.jl:1190

# %%
imgs = MNIST.images();
lbls = MNIST.labels();

# %%
img = imgs[1]
# Out:
# 28×28 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
# ...

# %%
typeof(img)
# Out:
# Array{Gray{Normed{UInt8,8}},2}

# %%
size(img)
# Out:
# (28, 28)

# %%
typeof(img[4, 16])
# Out:
# Gray{Normed{UInt8,8}}

# %%
g11 = gray(img[1, 1])
typeof(g11)
UInt8(g11)

g79 = gray(img[7, 9])
typeof(g79)
floor(g79 * 255)
UInt8(floor(g79 * 255))
# Out:
# 0x1e

# %%
for i in 1:size(img)[1], j in 1:size(img)[2]
    println("$i $j $(gray(img[i, j]))")
end
# Out:
# 1 1 0.0N0f8
# 1 2 0.0N0f8
# 1 3 0.0N0f8
# 1 4 0.0N0f8
# 1 5 0.0N0f8
# 1 6 0.0N0f8
# 1 7 0.0N0f8
# 1 8 0.0N0f8
# 1 9 0.0N0f8
# 1 10 0.0N0f8
# 1 11 0.0N0f8
# 1 12 0.0N0f8
# 1 13 0.0N0f8
# 1 14 0.0N0f8
# 1 15 0.0N0f8
# 1 16 0.0N0f8
# 1 17 0.0N0f8
# 1 18 0.0N0f8
# 1 19 0.0N0f8
# 1 20 0.0N0f8
# 1 21 0.0N0f8
# 1 22 0.0N0f8
# 1 23 0.0N0f8
# 1 24 0.0N0f8
# 1 25 0.0N0f8
# 1 26 0.0N0f8
# 1 27 0.0N0f8
# 1 28 0.0N0f8
# 2 1 0.0N0f8
# 2 2 0.0N0f8
# 2 3 0.0N0f8
# 2 4 0.0N0f8
# 2 5 0.0N0f8
# 2 6 0.0N0f8
# 2 7 0.0N0f8
# 2 8 0.0N0f8
# 2 9 0.0N0f8
# 2 10 0.0N0f8
# 2 11 0.0N0f8
# 2 12 0.0N0f8
# 2 13 0.0N0f8
# 2 14 0.0N0f8
# 2 15 0.0N0f8
# 2 16 0.0N0f8
# 2 17 0.0N0f8
# 2 18 0.0N0f8
# 2 19 0.0N0f8
# 2 20 0.0N0f8
# 2 21 0.0N0f8
# 2 22 0.0N0f8
# 2 23 0.0N0f8
# 2 24 0.0N0f8
# 2 25 0.0N0f8
# 2 26 0.0N0f8
# 2 27 0.0N0f8
# 2 28 0.0N0f8
# 3 1 0.0N0f8
# 3 2 0.0N0f8
# 3 3 0.0N0f8
# 3 4 0.0N0f8
# 3 5 0.0N0f8
# 3 6 0.0N0f8
# 3 7 0.0N0f8
# 3 8 0.0N0f8
# 3 9 0.0N0f8
# 3 10 0.0N0f8
# 3 11 0.0N0f8
# 3 12 0.0N0f8
# ...
